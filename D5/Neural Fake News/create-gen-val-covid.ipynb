# %%
import pandas as pd

json_df = pd.read_json('covid_fake_gen.jsonl', lines=True)

# %%
json_df
# Out:
#     url  summary authors publish_date           status       warc_date split  \
# 0            NaN      []   04-19-2019  success_wayback  20190424064330   gen
# 1            NaN      []   04-19-2019  success_wayback  20190424064330   gen
# 2            NaN      []   04-19-2019  success_wayback  20190424064330   gen
# 3            NaN      []   04-19-2019  success_wayback  20190424064330   gen
# 4            NaN      []   04-19-2019  success_wayback  20190424064330   gen
# ..   ..      ...     ...          ...              ...             ...   ...
# 228          NaN      []   04-19-2019  success_wayback  20190424064330   gen
# 229          NaN      []   04-19-2019  success_wayback  20190424064330   gen
# 230          NaN      []   04-19-2019  success_wayback  20190424064330   gen
# 231          NaN      []   04-19-2019  success_wayback  20190424064330   gen
# 232          NaN      []   04-19-2019  success_wayback  20190424064330   gen
#
#      inst_index              domain  \
# ...

# %%
json_df['true'] = 0

new_json_df = json_df.iloc[:, [12,-1]]
new_json_df['original_title'] = json_df.title
# Out:
# C:\Users\matti\AppData\Local\Temp\ipykernel_11052\1109241673.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_json_df['original_title'] = json_df.title

# %%
new_json_df
# Out:
#                                             gens_title  true  \
# 0    [Vizianagar Hatcheries chairman says people sh...     0
# 1                                           [Opinion:]     0
# 2    [Outrage as video shows Saudis in front of vir...     0
# 3    [Cepheid Says It's Developing an Automated Mic...     0
# 4    [What we know about the deadly haemorrhagic co...     0
# ..                                                 ...   ...
# 228  [New drug treating patient with 'serious, imme...     0
# 229  [Woman driven out of grocery store by angry mo...     0
# 230  [China Has Tried To Cover Up Its Own Coronavir...     0
# 231  [Facebook allows fake news while reporting ram...     0
# 232  [Nearly One-Month Old Relief Package Provision...     0
#
#                                         original_title
# 0          ‘Corona won’t affect chickens’, Health News
# 1    Dr. Brownstein: Corona Virus is Nothing New – ...
# 2           how Corona Virus patient shivers violently
# ...

# %%
for i in range(len(new_json_df)):
    new_json_df.iat[i, 0] = new_json_df.iat[i,0][0]

# %%
new_json_df
# Out:
#                                             gens_title  true  \
# 0    Vizianagar Hatcheries chairman says people sho...     0
# 1                                             Opinion:     0
# 2    Outrage as video shows Saudis in front of vira...     0
# 3    Cepheid Says It's Developing an Automated Micr...     0
# 4    What we know about the deadly haemorrhagic cor...     0
# ..                                                 ...   ...
# 228  New drug treating patient with 'serious, immed...     0
# 229  Woman driven out of grocery store by angry mob...     0
# 230  China Has Tried To Cover Up Its Own Coronaviru...     0
# 231  Facebook allows fake news while reporting ramp...     0
# 232  Nearly One-Month Old Relief Package Provisione...     0
#
#                                         original_title
# 0          ‘Corona won’t affect chickens’, Health News
# 1    Dr. Brownstein: Corona Virus is Nothing New – ...
# 2           how Corona Virus patient shivers violently
# ...

# %%
new_json_df.to_csv('covid_gen_val.tsv', sep='\t', index=False)
