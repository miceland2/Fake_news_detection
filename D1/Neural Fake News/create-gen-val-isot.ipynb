# %%
import pandas as pd

json_df = pd.read_json('isot_fake_gen_full.jsonl', lines=True)

# %%
json_df
# Out:
#      url  summary authors publish_date           status       warc_date split  \
# 0             NaN      []   04-19-2019  success_wayback  20190424064330   gen
# 1             NaN      []   04-19-2019  success_wayback  20190424064330   gen
# 2             NaN      []   04-19-2019  success_wayback  20190424064330   gen
# 3             NaN      []   04-19-2019  success_wayback  20190424064330   gen
# 4             NaN      []   04-19-2019  success_wayback  20190424064330   gen
# ...   ..      ...     ...          ...              ...             ...   ...
# 4648          NaN      []   04-19-2019  success_wayback  20190424064330   gen
# 4649          NaN      []   04-19-2019  success_wayback  20190424064330   gen
# 4650          NaN      []   04-19-2019  success_wayback  20190424064330   gen
# 4651          NaN      []   04-19-2019  success_wayback  20190424064330   gen
# 4652          NaN      []   04-19-2019  success_wayback  20190424064330   gen
#
# ...

# %%
json_df['true'] = 0

new_json_df = json_df.iloc[:, [12,-1]]
new_json_df['original_title'] = json_df.title
# Out:
# C:\Users\matti\AppData\Local\Temp\ipykernel_8492\1109241673.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_json_df['original_title'] = json_df.title

# %%
new_json_df
# Out:
#                                              gens_title  true  \
# 0     [Sarah Sanders continues winning the Washingto...     0
# 1     [B.C. Leads Liberal Fight Against Trump’s Huma...     0
# 2            [Bank robbery warrant out for Chicago man]     0
# 3     [Fox News Comptroller Fired for Racist Comment...     0
# 4     [Somali-Immigrant Serial Killer Handed Another...     0
# ...                                                 ...   ...
# 4648  [The Nomad Drone 2 is your friend to celebrate...     0
# 4649  [Obamacare Repeal Seems to Leak From Twitter U...     0
# 4650  [VIDEO: The Washington Post Kids Chorus sings ...     0
# 4651  [George Soros Wants To 'Theft' Hungary's Borders]     0
# 4652  [Another racist white professor wonders: "Can ...     0
#
#                                          original_title
# 0     NBC REPORTER Asks Sarah Sanders About Taxes…Sh...
# 1     DEADBEATS BEWARE: Trump’s Food Stamp Reform Is...
# ...

# %%
for i in range(len(new_json_df)):
    new_json_df.iat[i, 0] = new_json_df.iat[i,0][0]

# %%
new_json_df
# Out:
#                                              gens_title  true  \
# 0     Sarah Sanders continues winning the Washington...     0
# 1     B.C. Leads Liberal Fight Against Trump’s Human...     0
# 2              Bank robbery warrant out for Chicago man     0
# 3     Fox News Comptroller Fired for Racist Comments...     0
# 4     Somali-Immigrant Serial Killer Handed Another ...     0
# ...                                                 ...   ...
# 4648  The Nomad Drone 2 is your friend to celebrate ...     0
# 4649  Obamacare Repeal Seems to Leak From Twitter Us...     0
# 4650  VIDEO: The Washington Post Kids Chorus sings T...     0
# 4651    George Soros Wants To 'Theft' Hungary's Borders     0
# 4652  Another racist white professor wonders: "Can t...     0
#
#                                          original_title
# 0     NBC REPORTER Asks Sarah Sanders About Taxes…Sh...
# 1     DEADBEATS BEWARE: Trump’s Food Stamp Reform Is...
# ...

# %%
new_json_df.to_csv('isot_gen_val_full.tsv', sep='\t', index=False)

# %%
new_json_df.iloc[10].gens_title
# Out:
# 'Man wants to rob bank to avoid living with his wife'

# %%
new_json_df.iloc[10].original_title
# Out:
# 'MAN WHO ROBBED A BANK To Get Away From His Wife Gets The Ultimate Punishment'

# %%
# to consider: 10, 17, 26, 29
